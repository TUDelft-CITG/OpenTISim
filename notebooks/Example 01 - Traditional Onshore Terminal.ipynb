# %% [markdown]
# # MSc Thesis - Hugo Stam

# %% [markdown]
# ### Example 01 - Traditional Onshore Terminal

# %% [markdown]
# <img src="Figures/system_layout_alternative_1.2.png" style="width:1000px">

# %% [markdown]
# ###### Investment Strategy Simulation - Adaptive terminal planning in the light of an uncertain future
# * [**0. Prepare inputs:**](#0.-Prepare-inputs)<br>
#    * [**0.1 Generate demand forecast scenario:**](#0.1-Generate-demand-forecast-scenario)<br>
#    * [**0.2 Generate vessels:**](#0.2-Generate-vessels)<br>
# * [**1. Instatiate system components:**](#1.-Instatiate-system-components)<br>
# * [**2. Start simulation:**](#2.-Strart-simulation)<br>
# * [**3. Report all elements:**](#3.-Report-all-elements)<br>

# %% [markdown]
# #### notes:

# %%
# packages for data handling
import numpy as np
import pandas as pd
import statistics as st

# packages related to time, space and id
import datetime, time
import platform
import random
from datetime import timedelta

# you need these dependencies packages related to the simulation
import simpy

# spatial libraries 
import shapely.geometry
from simplekml import Kml, Style

# packages for figures
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns
# sns.set(style="ticks")
# sns.set(style="darkgrid")

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# OpenTISim package
from opentisim import container_objects
from opentisim import container_defaults
from opentisim import container_system

# OpenCLSim package
import openclsim.core as core
import openclsim.model as model
import openclsim.plot as plot

# Additional import to save the initialisation of the simulation
import openclsim.savesim as savesim

# Pretty-print a Python object to a stream
from pprint import pprint

# Jupyter Widgets
import ipywidgets as widgets

# Scroll to specific cell
from jupyter_helpers.utilities import scroll_to_current_cell

# %% [markdown]
# # 0. Prepare inputs

# %%
# iPython Widgests
annual_demand = widgets.IntSlider(
    value=1000000, min=500000, max=1500000, step=50000,
    description='Demand:', orientation='horizontal',
    readout=True, readout_format='d')

offshore_onshore_distance = widgets.IntSlider(
    value=40, min=20, max=60, step=20,
    description='Distance:', orientation='horizontal',
    readout=True, readout_format='d')

container_ship = widgets.Dropdown(
    options=[('Post Panamax I (6,000 TEU)', 6000), 
             ('New-Panamax (12,500 TEU)', 12500), 
             ('ULCS (21,000 TEU)', 21000)],
    value=12500, 
    description='Capacity:')

barge = widgets.Dropdown(
    options=[('Small (200 TEU)', 200), 
             ('Medium (250 TEU)', 250), 
             ('Large (300 TEU)', 300)],
    value=250, 
    description='Barge capacity:')

life_cycle = widgets.IntSlider(
    value=10, min=5, max=30, step=5,
    description='Life cycle:', orientation='horizontal',
    readout=True, readout_format='d')

print('Input Values')
display(annual_demand, offshore_onshore_distance, container_ship, barge, life_cycle)
# Out:
# Input Values
# IntSlider(value=1000000, description='Demand:', max=1500000, min=500000, step=50000)
# IntSlider(value=40, description='Distance:', max=60, min=20, step=20)
# Dropdown(description='Capacity:', index=1, options=(('Post Panamax I (6,000 TEU)', 6000), ('New-Panamax (12,50…
# Dropdown(description='Barge capacity:', index=1, options=(('Small (200 TEU)', 200), ('Medium (250 TEU)', 250),…
# IntSlider(value=10, description='Life cycle:', max=30, min=5, step=5)

# %%
offshore_distance = offshore_onshore_distance.value
demand = annual_demand.value
design_container = container_ship.value
design_barge = barge.value
lifecycle = life_cycle.value

print('The offshore distance:', offshore_distance, 'km')
print('The annual demand:', demand, 'TEU')
print('The design container ship capacity:', design_container, 'TEU')
print('The design barge capacity:', design_barge, 'TEU')
print('The design life cycle:', lifecycle, 'years')

avg_parcel = design_container / 8

startyear = 2020
# Out:
# The offshore distance: 40 km
# The annual demand: 1000000 TEU
# The design container ship capacity: 12500 TEU
# The design barge capacity: 250 TEU
# The design life cycle: 10 years

# %% [markdown]
# ## 0.1 Generate demand forecast scenario

# %%
# %store -r total_ocean_transport

# demand = []

# for year in years:
#     if year < 2025:
#         demand.append(total_ocean_transport)
#     elif year < 2030:
#         demand.append(total_ocean_transport * 1.5)
#     else:
#         demand.append(total_ocean_transport * 2.0)

# plt.plot(years, demand, 'o')
# plt.ylabel('Demand [TEU]')
# plt.ylim(0,)

# %%
years = list(range(startyear, startyear + lifecycle))
        
scenario_data={'year': years, 'volume': demand}

# instantiate Commodity objects, the inputs for the Commodity class
if design_container == 6000:
    container_defaults.container_data['post_panamax_I_perc'] = 100
    container_defaults.container_data['new_panamax_perc'] = 0
    container_defaults.container_data['ULCS_perc'] = 0

if design_container == 12500:
    container_defaults.container_data['post_panamax_I_perc'] = 0
    container_defaults.container_data['new_panamax_perc'] = 100
    container_defaults.container_data['ULCS_perc'] = 0
    
if design_container == 21000:
    container_defaults.container_data['post_panamax_I_perc'] = 0
    container_defaults.container_data['new_panamax_perc'] = 0
    container_defaults.container_data['ULCS_perc'] = 100
    
# print(container_defaults.container_data)

# ladens
container = container_objects.Commodity(**container_defaults.container_data)
container.scenario_data = pd.DataFrame(data=scenario_data)
# print(container.scenario_data)

# combine
demand = [container]

# %% [markdown]
# ## 0.2 Generate vessels

# %%
# instantiate vessels
fully_cellular = container_objects.Vessel(**container_defaults.fully_cellular_data)
panamax = container_objects.Vessel(**container_defaults.panamax_data)
panamax_max = container_objects.Vessel(**container_defaults.panamax_max_data)
post_panamax_I = container_objects.Vessel(**container_defaults.post_panamax_I_data)
post_panamax_II = container_objects.Vessel(**container_defaults.post_panamax_II_data)
new_panamax = container_objects.Vessel(**container_defaults.new_panamax_data)
VLCS = container_objects.Vessel(**container_defaults.VLCS_data)
ULCS = container_objects.Vessel(**container_defaults.ULCS_data)

vessels = [fully_cellular, panamax, panamax_max, post_panamax_I, post_panamax_II, new_panamax, VLCS, ULCS]

# %% [markdown]
# # 1. Instatiate system components

# %% [markdown]
# ## 1.1 Terminal system
#
# Specify the variables

# %%
Terminal = container_system.System(startyear = startyear,
                                   lifecycle = lifecycle,
                                   stack_equipment='rs',
                                   laden_stack='rs',
                                   crane_type_defaults=container_defaults.sts_crane_data,
                                   system_layout='traditional_onshore',
                                   allowable_berth_occupancy = 0.70,
                                   transhipment_ratio = 0.0,
                                   elements = demand + vessels,
                                   laden_perc = 0.80, 
                                   reefer_perc = 0.10, 
                                   empty_perc = 0.05, 
                                   oog_perc = 0.05,
                                   operational_hours = 8640,     # 360 days 
                                   debug=True)                   # provide intermediate outputs via print statements

# %% [markdown]
# # 2. Start simulation

# %% [markdown]
# This method automatically generates investment decisions, parametrically derived from demand trends and a number of investment triggers.
#
# Apply frame of reference style decisions while stepping through each year of the terminal lifecycle and check if investment is needed (in light of strategic objective, operational objective, QSC, decision recipe, intervention method):
#     1. for each year evaluate the demand of each commodity (see 0.1 Demand forecast scenario)
#     2. for each year evaluate the various investment decisions
#     3. for each year calculate the energy costs (requires insight in realized demands)
#     4. for each year calculate the demurrage costs (requires insight in realized demands)
#     5. for each year calculate terminal revenues
#     6. collect all cash flows (capex, opex, revenues)
#     7. calculate PV's and aggregate to NPV

# %%
Terminal.simulate()
# Out:
# Below, the various investment decisions are evaluated for the year 2020.
#
# Simulate year: 2020
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 0 [] is online; 0 total planned
#      a total of 0 [] is online; 0 total planned
#      a total of 0 [] is online; 0 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): inf
#      Berth occupancy online  (@ start of year): inf
#      Crane occupancy planned (@ start of year): inf
#      Crane occupancy online  (@ start of year): inf
#
#   *** add Berth to elements
#      Berth occupancy planned (after adding Berth): inf
#      Berth occupancy online  (after adding Berth): inf
#
#   *** add Quay to elements
# index-list 10
#      Berth occupancy planned (after adding Quay): inf
#      Berth occupancy online  (after adding Quay): inf
#
#   *** add STS crane to elements
# index-list 10
#    > Total time at berth (planned) is 29481.0 h / 8640 oh
#      Berth occupancy planned (after adding Crane): 3.412
#      Berth occupancy online  (after adding Crane): inf
#
#   *** add STS crane to elements
# index-list 10
#    > Total time at berth (planned) is 16661.0 h / 8640 oh
#      Berth occupancy planned (after adding Crane): 1.928
#      Berth occupancy online  (after adding Crane): inf
#
#   *** add STS crane to elements
# index-list 10
#    > Total time at berth (planned) is 12387.0 h / 8640 oh
#      Berth occupancy planned (after adding Crane): 1.434
#      Berth occupancy online  (after adding Crane): inf
#
#   *** add Berth to elements
#    > Total time at berth (planned) is 10467.0 h / 8640 oh
#      Berth occupancy planned (after adding Berth): 1.211
#      Berth occupancy online  (after adding Berth): inf
#
#   *** add Quay to elements
# index-list 10
#    > Total time at berth (planned) is 10467.0 h / 8640 oh
#      Berth occupancy planned (after adding Quay): 1.211
#      Berth occupancy online  (after adding Quay): inf
#
#   *** add STS crane to elements
# index-list 10
#    > Total time at berth (planned) is 8330.0 h / 8640 oh
#      Berth occupancy planned (after adding Crane): 0.964
#      Berth occupancy online  (after adding Crane): inf
#
#   *** add STS crane to elements
# index-list 10
#    > Total time at berth (planned) is 7048.0 h / 8640 oh
#      Berth occupancy planned (after adding Crane): 0.816
#      Berth occupancy online  (after adding Crane): inf
#
#   *** add STS crane to elements
# index-list 10
#    > Total time at berth (planned) is 6194.0 h / 8640 oh
#      Berth occupancy planned (after adding Crane): 0.717
#      Berth occupancy online  (after adding Crane): inf
#
#   *** add Berth to elements
#    > Total time at berth (planned) is 5554.0 h / 8640 oh
#      Berth occupancy planned (after adding Berth): 0.643
#      Berth occupancy online  (after adding Berth): inf
#
#   *** add Quay to elements
# index-list 10
#    > Total time at berth (planned) is 5554.0 h / 8640 oh
#      Berth occupancy planned (after adding Quay): 0.643
#      Berth occupancy online  (after adding Quay): inf
#
#   *** add STS crane to elements
# index-list 10
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#      Berth occupancy planned (after adding Crane): 0.572
#      Berth occupancy online  (after adding Crane): inf
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 0
#      Number of STS cranes        (@ start of year): 0
#
#      Stack Capacity planned  (@ start of year): 0
#      Stack Capacity online   (@ start of year): 0
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# c:\checkouts\opentisim\opentisim\container_system.py:1639: FutureWarning:
#
# `item` has been deprecated and will be removed in a future version
#
# c:\checkouts\opentisim\opentisim\container_system.py:2126: FutureWarning:
#
# `item` has been deprecated and will be removed in a future version
#
# c:\checkouts\opentisim\opentisim\container_system.py:1687: FutureWarning:
#
# `item` has been deprecated and will be removed in a future version
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#   *** add Laden Stack to elements
# index-list 10
#      Empty Stack capacity planned  (@ start of year): 0
#      Empty Stack capacity online   (@ start of year): 0
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#   *** add Empty Stack to elements
# index-list 10
#   *** add Empty Stack to elements
# index-list 10
#   *** add Empty Stack to elements
# index-list 10
#   *** add Empty Stack to elements
# index-list 10
#   *** add Empty Stack to elements
# index-list 10
#      OOG Slots planned  (@ start of year): 0
#      OOG Slots online   (@ start of year): 0
#      OOG Slots required (@ start of year): 478
#
#   *** add OOG stack to elements
# index-list 10
#   *** add OOG stack to elements
# index-list 10
#   *** add OOG stack to elements
# index-list 10
#   *** add OOG stack to elements
# index-list 10
#   *** add OOG stack to elements
# index-list 10
#      Number of stack Equipment online (@ start of year): 0
#
#      Gate capacity planned     (@ start of year): 0
#      Gate capacity online      (@ start of year): 0
#      Gate service rate planned (@ start of year): inf
#      Gate lane minutes         (@ start of year): 0
#
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#   *** add Gate to elements
# index-list 10
#      Empty Handlers online (@ start of year): 0
#
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#
# Below, the various investment decisions are evaluated for the year 2021.
#
# Simulate year: 2021
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 0 Quay is online; 3 total planned
#      a total of 0 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): inf
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): inf
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 0
#      Number of STS cranes        (@ start of year): 0
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 0
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 0
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 0
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 0
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 0
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#   *** add General Services to elements
# index-list 10
#
# Below, the various investment decisions are evaluated for the year 2022.
#
# Simulate year: 2022
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 0
#      Number of STS cranes        (@ start of year): 7
#
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#   *** add Tractor to elements
# index-list 10
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 0
#
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#   *** add Stack Equipment to elements
# index-list 10
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#
# Below, the various investment decisions are evaluated for the year 2023.
#
# Simulate year: 2023
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 35
#      Number of STS cranes        (@ start of year): 7
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 28
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#
# Below, the various investment decisions are evaluated for the year 2024.
#
# Simulate year: 2024
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 35
#      Number of STS cranes        (@ start of year): 7
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 28
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#
# Below, the various investment decisions are evaluated for the year 2025.
#
# Simulate year: 2025
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 35
#      Number of STS cranes        (@ start of year): 7
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 28
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#
# Below, the various investment decisions are evaluated for the year 2026.
#
# Simulate year: 2026
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 35
#      Number of STS cranes        (@ start of year): 7
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 28
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#
# Below, the various investment decisions are evaluated for the year 2027.
#
# Simulate year: 2027
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 35
#      Number of STS cranes        (@ start of year): 7
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 28
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#
# Below, the various investment decisions are evaluated for the year 2028.
#
# Simulate year: 2028
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 35
#      Number of STS cranes        (@ start of year): 7
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 28
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
#
#
# Below, the various investment decisions are evaluated for the year 2029.
#
# Simulate year: 2029
#   Total vessel calls: 640
#   Fully cellular calls: 0
#   Panamax calls: 0
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 640
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 3 Berth is online; 3 total planned
#      a total of 3 Quay is online; 3 total planned
#      a total of 7 STS_crane is online; 7 total planned
#
#   Start analysis:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#      Berth occupancy planned (@ start of year): 0.572
#      Berth occupancy online  (@ start of year): 0.572
#      Crane occupancy planned (@ start of year): 0.424
#      Crane occupancy online  (@ start of year): 0.424
#
#    > Quay capacity planned 235871.99999999997 TEU per year
#    > Quay capacity planned 471743.99999999994 TEU per year
#    > Quay capacity planned 707615.9999999999 TEU per year
#    > Quay capacity planned 943487.9999999999 TEU per year
#    > Quay capacity planned 1179359.9999999998 TEU per year
#    > Quay capacity planned 1415231.9999999998 TEU per year
#    > Quay capacity planned 1651103.9999999998 TEU per year
#    > Throughput online 1000000 TEU per year
#      Horizontal Transport online (@ start of year): 35
#      Number of STS cranes        (@ start of year): 7
#
#      Stack Capacity planned  (@ start of year): 13120
#      Stack Capacity online   (@ start of year): 13120
#      Stack Capacity required (@ start of year): 12912
#      Total Laden and Reefer Ground Slots required (@ start of year): 3228
#
#      Empty Stack capacity planned  (@ start of year): 2400
#      Empty Stack capacity online   (@ start of year): 2400
#      Empty Stack capacity required (@ start of year): 2381
#      Empty Ground Slots required   (@ start of year): 397
#
#      OOG Slots planned  (@ start of year): 500
#      OOG Slots online   (@ start of year): 500
#      OOG Slots required (@ start of year): 478
#
#      Number of stack Equipment online (@ start of year): 28
#
#      Gate capacity planned     (@ start of year): 600
#      Gate capacity online      (@ start of year): 600
#      Gate service rate planned (@ start of year): 0.901
#      Gate lane minutes         (@ start of year): 541
#
#      Empty Handlers online (@ start of year): 35
# c:\checkouts\opentisim\opentisim\container_system.py:565: FutureWarning:
#
# `item` has been deprecated and will be removed in a future version
# PV: [-7.72257906e+07 -2.35405267e+08 -3.71302024e+07 -3.26940663e+07
#  -2.87879383e+07 -2.53484954e+07 -2.23199804e+07 -1.96532976e+07
#  -1.73052172e+07 -1.52376740e+07]
# NPV: -511107928.86766136

# %% [markdown]
# ## 3. Report all elements

# %%
if True: 
    for element in Terminal.elements:
        print("")
        print(element.name)
        print("")
        print(element.__dict__) # This is the dictionary containing the module's symbol table. 
        # object.__dict__ A dictionary or other mapping object used to store an object's (writable) attributes.
# Out:
# Laden
#
# {'historic_data': [], 'scenario_data':    year   volume
# 0  2020  1000000
# 1  2021  1000000
# 2  2022  1000000
# 3  2023  1000000
# 4  2024  1000000
# 5  2025  1000000
# 6  2026  1000000
# 7  2027  1000000
# 8  2028  1000000
# 9  2029  1000000, 'handling_fee': 150, 'fully_cellular_perc': 0, 'panamax_perc': 0, 'panamax_max_perc': 0, 'post_panamax_I_perc': 0, 'post_panamax_II_perc': 0, 'new_panamax_perc': 100, 'VLCS_perc': 0, 'ULCS_perc': 0, 'name': 'Laden', 'id': 'fb0d07e4-150e-11ea-90c8-04d3b0b539c4'}
#
# Fully_Cellular_1
#
# {'type': 'Fully_Cellular', 'starting_time': 0, 'call_size': 312.5, 'LOA': 215, 'draught': 10.0, 'beam': 20.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'transport_costs': 200, 'name': 'Fully_Cellular_1', 'id': 'fb0dcac0-150e-11ea-8d9d-04d3b0b539c4'}
#
# Panamax_1
#
# {'type': 'Panamax', 'starting_time': 0, 'call_size': 425.0, 'LOA': 250, 'draught': 12.5, 'beam': 32.2, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'transport_costs': 180, 'name': 'Panamax_1', 'id': 'fb0df236-150e-11ea-bd1c-04d3b0b539c4'}
#
# Panamax_Max_1
#
# {'type': 'Panamax_Max', 'starting_time': 0, 'call_size': 562.5, 'LOA': 290, 'draught': 12.5, 'beam': 32.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 2, 'demurrage_rate': 730, 'transport_costs': 160, 'name': 'Panamax_Max_1', 'id': 'fb0df237-150e-11ea-9179-04d3b0b539c4'}
#
# Post_Panamax_I_1
#
# {'type': 'Post_Panamax_I', 'starting_time': 0, 'call_size': 750.0, 'LOA': 300, 'draught': 13.0, 'beam': 40.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 2, 'demurrage_rate': 730, 'transport_costs': 150, 'name': 'Post_Panamax_I_1', 'id': 'fb0df238-150e-11ea-adf4-04d3b0b539c4'}
#
# Post_Panamax_II_1
#
# {'type': 'Post_Panamax_II', 'starting_time': 0, 'call_size': 1062.5, 'LOA': 340, 'draught': 14.5, 'beam': 43.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 2, 'demurrage_rate': 730, 'transport_costs': 140, 'name': 'Post_Panamax_II_1', 'id': 'fb0df239-150e-11ea-aac2-04d3b0b539c4'}
#
# New_Panamax_1
#
# {'type': 'New_Panamax', 'starting_time': 0, 'call_size': 1562.5, 'LOA': 366, 'draught': 15.2, 'beam': 49.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'transport_costs': 120, 'name': 'New_Panamax_1', 'id': 'fb0df23a-150e-11ea-a412-04d3b0b539c4'}
#
# VLCS_1
#
# {'type': 'VLCS', 'starting_time': 0, 'call_size': 1875.0, 'LOA': 397, 'draught': 15.5, 'beam': 56.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'transport_costs': 80, 'name': 'VLCS_1', 'id': 'fb0df23b-150e-11ea-962b-04d3b0b539c4'}
#
# ULCS_1
#
# {'type': 'ULCS', 'starting_time': 0, 'call_size': 2625.0, 'LOA': 400, 'draught': 16.0, 'beam': 59.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'transport_costs': 60, 'name': 'ULCS_1', 'id': 'fb0df23c-150e-11ea-a94a-04d3b0b539c4'}
#
# Berth
#
# {'triggers': [], 'renevue': [], 'labour': [], 'maintenance': [], 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': [], 'crane_type': 'Mobile cranes', 'max_cranes': 3, 'delivery_time': 1, 'year_purchase': [], 'year_online': 2021, 'name': 'Berth', 'id': 'fb105a1e-150e-11ea-b5d2-04d3b0b539c4'}
#
# Quay
#
# {'land_use': 28165.0, 'triggers': [], 'renevue': [], 'labour': [], 'maintenance': 345371.7, 'energy': [], 'insurance': 345371.7, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 40557795, 'year_purchase': [], 'year_online': 2022, 'ownership': 'Port authority', 'delivery_time': 2, 'lifespan': 50, 'mobilisation_min': 2500000, 'mobilisation_perc': 0.02, 'maintenance_perc': 0.01, 'insurance_perc': 0.01, 'freeboard': 4, 'Gijt_constant': 757.8, 'Gijt_coefficient': 1.2729, 'max_sinkage': 0.5, 'wave_motion': 0.5, 'safety_margin': 0.5, 'apron_width': 65.5, 'apron_pavement': 125, 'name': 'Quay', 'id': 'fb105a20-150e-11ea-9a2f-04d3b0b539c4', 'df':    Year       Capex  Maintenance  insurance
# 0  2020  24334677.0          0.0        0.0
# 1  2021  16223118.0          0.0        0.0
# 2  2022         0.0     345371.7   345371.7
# 3  2023         0.0     345371.7   345371.7
# 4  2024         0.0     345371.7   345371.7
# 5  2025         0.0     345371.7   345371.7
# 6  2026         0.0     345371.7   345371.7
# 7  2027         0.0     345371.7   345371.7
# 8  2028         0.0     345371.7   345371.7
# 9  2029         0.0     345371.7   345371.7}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 913846.1538461538, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 0.75, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 39, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fb118ec0-150e-11ea-8f0a-04d3b0b539c4', 'shift': 36.55384615384615, 'df':    Year       Capex  Maintenance  insurance         Labour         Energy
# 0  2020         0.0          0.0        0.0       0.000000       0.000000
# 1  2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2  2022         0.0     200000.0   100000.0  913846.153846  123913.097143
# 3  2023         0.0     200000.0   100000.0  913846.153846  123913.097143
# 4  2024         0.0     200000.0   100000.0  913846.153846  123913.097143
# 5  2025         0.0     200000.0   100000.0  913846.153846  123913.097143
# 6  2026         0.0     200000.0   100000.0  913846.153846  123913.097143
# 7  2027         0.0     200000.0   100000.0  913846.153846  123913.097143
# 8  2028         0.0     200000.0   100000.0  913846.153846  123913.097143
# 9  2029         0.0     200000.0   100000.0  913846.153846  123913.097143}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 913846.1538461538, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 0.75, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 39, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fb12c51c-150e-11ea-b4e8-04d3b0b539c4', 'shift': 36.55384615384615, 'df':    Year       Capex  Maintenance  insurance         Labour         Energy
# 0  2020         0.0          0.0        0.0       0.000000       0.000000
# 1  2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2  2022         0.0     200000.0   100000.0  913846.153846  123913.097143
# 3  2023         0.0     200000.0   100000.0  913846.153846  123913.097143
# 4  2024         0.0     200000.0   100000.0  913846.153846  123913.097143
# 5  2025         0.0     200000.0   100000.0  913846.153846  123913.097143
# 6  2026         0.0     200000.0   100000.0  913846.153846  123913.097143
# 7  2027         0.0     200000.0   100000.0  913846.153846  123913.097143
# 8  2028         0.0     200000.0   100000.0  913846.153846  123913.097143
# 9  2029         0.0     200000.0   100000.0  913846.153846  123913.097143}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 913846.1538461538, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 0.75, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 39, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fb13fe12-150e-11ea-a0ff-04d3b0b539c4', 'shift': 36.55384615384615, 'df':    Year       Capex  Maintenance  insurance         Labour         Energy
# 0  2020         0.0          0.0        0.0       0.000000       0.000000
# 1  2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2  2022         0.0     200000.0   100000.0  913846.153846  123913.097143
# 3  2023         0.0     200000.0   100000.0  913846.153846  123913.097143
# 4  2024         0.0     200000.0   100000.0  913846.153846  123913.097143
# 5  2025         0.0     200000.0   100000.0  913846.153846  123913.097143
# 6  2026         0.0     200000.0   100000.0  913846.153846  123913.097143
# 7  2027         0.0     200000.0   100000.0  913846.153846  123913.097143
# 8  2028         0.0     200000.0   100000.0  913846.153846  123913.097143
# 9  2029         0.0     200000.0   100000.0  913846.153846  123913.097143}
#
# Berth
#
# {'triggers': [], 'renevue': [], 'labour': [], 'maintenance': [], 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': [], 'crane_type': 'Mobile cranes', 'max_cranes': 3, 'delivery_time': 1, 'year_purchase': [], 'year_online': 2021, 'name': 'Berth', 'id': 'fb150cae-150e-11ea-a3df-04d3b0b539c4'}
#
# Quay
#
# {'land_use': 31636.500000000007, 'triggers': [], 'renevue': [], 'labour': [], 'maintenance': 387940.7700000001, 'energy': [], 'insurance': 387940.7700000001, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 45248639, 'year_purchase': [], 'year_online': 2022, 'ownership': 'Port authority', 'delivery_time': 2, 'lifespan': 50, 'mobilisation_min': 2500000, 'mobilisation_perc': 0.02, 'maintenance_perc': 0.01, 'insurance_perc': 0.01, 'freeboard': 4, 'Gijt_constant': 757.8, 'Gijt_coefficient': 1.2729, 'max_sinkage': 0.5, 'wave_motion': 0.5, 'safety_margin': 0.5, 'apron_width': 65.5, 'apron_pavement': 125, 'name': 'Quay', 'id': 'fb150cb0-150e-11ea-a313-04d3b0b539c4', 'df':    Year       Capex  Maintenance  insurance
# 0  2020  27149183.4         0.00       0.00
# 1  2021  18099455.6         0.00       0.00
# 2  2022         0.0    387940.77  387940.77
# 3  2023         0.0    387940.77  387940.77
# 4  2024         0.0    387940.77  387940.77
# 5  2025         0.0    387940.77  387940.77
# 6  2026         0.0    387940.77  387940.77
# 7  2027         0.0    387940.77  387940.77
# 8  2028         0.0    387940.77  387940.77
# 9  2029         0.0    387940.77  387940.77}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 913846.1538461538, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 0.75, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 39, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fb16661e-150e-11ea-9c5a-04d3b0b539c4', 'shift': 36.55384615384615, 'df':    Year       Capex  Maintenance  insurance         Labour         Energy
# 0  2020         0.0          0.0        0.0       0.000000       0.000000
# 1  2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2  2022         0.0     200000.0   100000.0  913846.153846  123913.097143
# 3  2023         0.0     200000.0   100000.0  913846.153846  123913.097143
# 4  2024         0.0     200000.0   100000.0  913846.153846  123913.097143
# 5  2025         0.0     200000.0   100000.0  913846.153846  123913.097143
# 6  2026         0.0     200000.0   100000.0  913846.153846  123913.097143
# 7  2027         0.0     200000.0   100000.0  913846.153846  123913.097143
# 8  2028         0.0     200000.0   100000.0  913846.153846  123913.097143
# 9  2029         0.0     200000.0   100000.0  913846.153846  123913.097143}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 913846.1538461538, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 0.75, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 39, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fb179e70-150e-11ea-86fb-04d3b0b539c4', 'shift': 36.55384615384615, 'df':    Year       Capex  Maintenance  insurance         Labour         Energy
# 0  2020         0.0          0.0        0.0       0.000000       0.000000
# 1  2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2  2022         0.0     200000.0   100000.0  913846.153846  123913.097143
# 3  2023         0.0     200000.0   100000.0  913846.153846  123913.097143
# 4  2024         0.0     200000.0   100000.0  913846.153846  123913.097143
# 5  2025         0.0     200000.0   100000.0  913846.153846  123913.097143
# 6  2026         0.0     200000.0   100000.0  913846.153846  123913.097143
# 7  2027         0.0     200000.0   100000.0  913846.153846  123913.097143
# 8  2028         0.0     200000.0   100000.0  913846.153846  123913.097143
# 9  2029         0.0     200000.0   100000.0  913846.153846  123913.097143}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 913846.1538461538, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 0.75, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 39, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fb18d106-150e-11ea-ab11-04d3b0b539c4', 'shift': 36.55384615384615, 'df':    Year       Capex  Maintenance  insurance         Labour         Energy
# 0  2020         0.0          0.0        0.0       0.000000       0.000000
# 1  2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2  2022         0.0     200000.0   100000.0  913846.153846  123913.097143
# 3  2023         0.0     200000.0   100000.0  913846.153846  123913.097143
# 4  2024         0.0     200000.0   100000.0  913846.153846  123913.097143
# 5  2025         0.0     200000.0   100000.0  913846.153846  123913.097143
# 6  2026         0.0     200000.0   100000.0  913846.153846  123913.097143
# 7  2027         0.0     200000.0   100000.0  913846.153846  123913.097143
# 8  2028         0.0     200000.0   100000.0  913846.153846  123913.097143
# 9  2029         0.0     200000.0   100000.0  913846.153846  123913.097143}
#
# Berth
#
# {'triggers': [], 'renevue': [], 'labour': [], 'maintenance': [], 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': [], 'crane_type': 'Mobile cranes', 'max_cranes': 3, 'delivery_time': 1, 'year_purchase': [], 'year_online': 2021, 'name': 'Berth', 'id': 'fb1a09d2-150e-11ea-b728-04d3b0b539c4'}
#
# Quay
#
# {'land_use': 29900.749999999993, 'triggers': [], 'renevue': [], 'labour': [], 'maintenance': 366656.2349999999, 'energy': [], 'insurance': 366656.2349999999, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 42903217, 'year_purchase': [], 'year_online': 2022, 'ownership': 'Port authority', 'delivery_time': 2, 'lifespan': 50, 'mobilisation_min': 2500000, 'mobilisation_perc': 0.02, 'maintenance_perc': 0.01, 'insurance_perc': 0.01, 'freeboard': 4, 'Gijt_constant': 757.8, 'Gijt_coefficient': 1.2729, 'max_sinkage': 0.5, 'wave_motion': 0.5, 'safety_margin': 0.5, 'apron_width': 65.5, 'apron_pavement': 125, 'name': 'Quay', 'id': 'fb1a22bb-150e-11ea-ab37-04d3b0b539c4', 'df':    Year       Capex  Maintenance   insurance
# 0  2020  25741930.2        0.000       0.000
# 1  2021  17161286.8        0.000       0.000
# 2  2022         0.0   366656.235  366656.235
# 3  2023         0.0   366656.235  366656.235
# 4  2024         0.0   366656.235  366656.235
# 5  2025         0.0   366656.235  366656.235
# 6  2026         0.0   366656.235  366656.235
# 7  2027         0.0   366656.235  366656.235
# 8  2028         0.0   366656.235  366656.235
# 9  2029         0.0   366656.235  366656.235}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 913846.1538461538, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 0.75, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 39, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fb1b558a-150e-11ea-9d52-04d3b0b539c4', 'shift': 36.55384615384615, 'df':    Year       Capex  Maintenance  insurance         Labour         Energy
# 0  2020         0.0          0.0        0.0       0.000000       0.000000
# 1  2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2  2022         0.0     200000.0   100000.0  913846.153846  123913.097143
# 3  2023         0.0     200000.0   100000.0  913846.153846  123913.097143
# 4  2024         0.0     200000.0   100000.0  913846.153846  123913.097143
# 5  2025         0.0     200000.0   100000.0  913846.153846  123913.097143
# 6  2026         0.0     200000.0   100000.0  913846.153846  123913.097143
# 7  2027         0.0     200000.0   100000.0  913846.153846  123913.097143
# 8  2028         0.0     200000.0   100000.0  913846.153846  123913.097143
# 9  2029         0.0     200000.0   100000.0  913846.153846  123913.097143}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb1ceaca-150e-11ea-99d9-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb1db538-150e-11ea-af44-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb1e7826-150e-11ea-a836-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb1f7a74-150e-11ea-a1e0-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb203d28-150e-11ea-a7ca-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb210014-150e-11ea-9904-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb21b89e-150e-11ea-9244-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2269c4-150e-11ea-8956-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb232c74-150e-11ea-bf92-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb23d8a0-150e-11ea-8b0a-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb24c2a2-150e-11ea-a8a4-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb255bac-150e-11ea-8f47-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb261f0a-150e-11ea-8624-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb26e68c-150e-11ea-9879-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb27aa6a-150e-11ea-b418-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2867e6-150e-11ea-99fb-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb292bf0-150e-11ea-afb7-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb29fe2c-150e-11ea-b425-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2ac27a-150e-11ea-bb86-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2b5e0a-150e-11ea-9f5a-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2c468a-150e-11ea-b8e0-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2d2cf4-150e-11ea-a31a-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2dc8d4-150e-11ea-8de0-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2eb19f-150e-11ea-9824-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# 2  2022        0.0     116280.0  52893.841463
# 3  2023        0.0     116280.0  52893.841463
# 4  2024        0.0     116280.0  52893.841463
# 5  2025        0.0     116280.0  52893.841463
# 6  2026        0.0     116280.0  52893.841463
# 7  2027        0.0     116280.0  52893.841463
# 8  2028        0.0     116280.0  52893.841463
# 9  2029        0.0     116280.0  52893.841463}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fb2fb9db-150e-11ea-893a-04d3b0b539c4', 'storage_area': 1440.0, 'df':    Year      Capex  Maintenance        Energy
# 0  2020        0.0          0.0      0.000000
# 1  2021  1312800.0          0.0      0.000000
# ...
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler

# %%
scroll_to_current_cell(preserve=True)
# Out:
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# Empty Handler
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 10000.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'empty_handler', 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 15, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.02, 'crew': 1, 'salary': 35000, 'fuel_consumption': 1.5, 'required': 5, 'year_purchase': [], 'year_online': 2022, 'name': 'Empty Handler', 'id': 'fb4f9223-150e-11ea-bb52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year     Capex  Maintenance         Labour         Fuel
# 0  2020       0.0          0.0       0.000000     0.000000
# 1  2021  505000.0          0.0       0.000000     0.000000
# 2  2022       0.0      10000.0  166153.846154  1524.171429
# 3  2023       0.0      10000.0  166153.846154  1524.171429
# 4  2024       0.0      10000.0  166153.846154  1524.171429
# 5  2025       0.0      10000.0  166153.846154  1524.171429
# 6  2026       0.0      10000.0  166153.846154  1524.171429
# 7  2027       0.0      10000.0  166153.846154  1524.171429
# 8  2028       0.0      10000.0  166153.846154  1524.171429
# 9  2029       0.0      10000.0  166153.846154  1524.171429}
#
# General_Services"
#
# {'year_purchase': [], 'year_online': 2022, 'type': 'general_services', 'office': 2400, 'office_cost': 1500, 'workshop': 2400, 'workshop_cost': 1000, 'fuel_station_cost': 500000, 'scanning_inspection_area': 2700, 'scanning_inspection_area_cost': 1000, 'lighting_mast_required': 1.2, 'lighting_mast_cost': 30000, 'firefight_cost': 2000000, 'maintenance_tools_cost': 10000000, 'terminal_operating_software_cost': 10000000, 'electrical_station_cost': 2000000, 'repair_building': 100, 'repair_building_cost': 1000, 'ceo': 1, 'secretary': 1, 'administration': 3, 'hr': 2, 'commercial': 1, 'operations': 4, 'engineering': 2, 'security': 2, 'general_maintenance': 0.015, 'crew_required': 500000, 'delivery_time': 1, 'lighting_consumption': 1, 'general_consumption': 1000, 'capex': 33319000.0, 'labour': [], 'maintenance': 499785.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'land_use': 7600, 'name': 'General_Services"', 'id': 'fb711a53-150e-11ea-8687-04d3b0b539c4', 'df':    Year       Capex  Maintenance        energy     Labour
# 0  2020         0.0          0.0  0.000000e+00        NaN
# 1  2021  33319000.0          0.0  0.000000e+00        NaN
# 2  2022         0.0     499785.0  1.526460e+06  2960000.0
# 3  2023         0.0     499785.0  1.526460e+06  2960000.0
# 4  2024         0.0     499785.0  1.526460e+06  2960000.0
# 5  2025         0.0     499785.0  1.526460e+06  2960000.0
# 6  2026         0.0     499785.0  1.526460e+06  2960000.0
# 7  2027         0.0     499785.0  1.526460e+06  2960000.0
# 8  2028         0.0     499785.0  1.526460e+06  2960000.0
# 9  2029         0.0     499785.0  1.526460e+06  2960000.0}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb72c0f7-150e-11ea-b120-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb73d376-150e-11ea-90fb-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb754778-150e-11ea-b745-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb774fd0-150e-11ea-b8e2-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb78d758-150e-11ea-82d2-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb79e9f6-150e-11ea-bb09-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb7aaef4-150e-11ea-9004-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb7b98b0-150e-11ea-9950-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb7c83b4-150e-11ea-ae13-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb7d5d48-150e-11ea-9d9c-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb7e47c2-150e-11ea-8a5a-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb7f058c-150e-11ea-a519-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb7fef24-150e-11ea-bd5c-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb80d552-150e-11ea-9def-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb81981e-150e-11ea-be2f-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb82a3d0-150e-11ea-a324-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb83669e-150e-11ea-8962-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb8450b4-150e-11ea-8c52-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb85394a-150e-11ea-bb22-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb85fbd4-150e-11ea-bcb9-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb86becc-150e-11ea-9f74-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb87bc7a-150e-11ea-adf9-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb888cd0-150e-11ea-bb08-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb89768c-150e-11ea-99d6-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb8a598a-150e-11ea-911c-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb8b28fe-150e-11ea-8986-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb8bee7e-150e-11ea-afca-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb8cd48c-150e-11ea-8ae0-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb8dbf8a-150e-11ea-92b1-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# 3  2023      0.0       8500.0  166153.846154  43734.057143
# 4  2024      0.0       8500.0  166153.846154  43734.057143
# 5  2025      0.0       8500.0  166153.846154  43734.057143
# 6  2026      0.0       8500.0  166153.846154  43734.057143
# 7  2027      0.0       8500.0  166153.846154  43734.057143
# 8  2028      0.0       8500.0  166153.846154  43734.057143
# 9  2029      0.0       8500.0  166153.846154  43734.057143}
#
# Tractor-trailer
#
# {'triggers': [], 'labour': 166153.84615384616, 'maintenance': 8500.0, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 86000, 'type': 'tractor_trailer', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 85000, 'mobilisation': 1000, 'maintenance_perc': 0.1, 'insurance_perc': 0.01, 'crew': 1, 'salary': 30000, 'utilisation': 0.8, 'fuel_consumption': 2, 'productivity': 1, 'required': 5, 'non_essential_moves': 1.2, 'year_purchase': [], 'year_online': 2022, 'name': 'Tractor-trailer', 'id': 'fb8ed19a-150e-11ea-954c-04d3b0b539c4', 'shift': 6.6461538461538465, 'df':    Year    Capex  Maintenance         Labour          Fuel
# 0  2020      0.0          0.0       0.000000      0.000000
# 1  2021  86000.0          0.0       0.000000      0.000000
# 2  2022      0.0       8500.0  166153.846154  43734.057143
# ...
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2022, 'name': 'Reach stacker', 'id': 'fb94ae32-150e-11ea-9a12-04d3b0b539c4', 'shift': 10, 'df':    Year     Capex  Maintenance    Labour      Fuel
# 0  2020       0.0          0.0       0.0      0.00
# 1  2021  505000.0          0.0       0.0      0.00
# 2  2022       0.0      50000.0  250000.0  62650.44
# 3  2023       0.0      50000.0  250000.0  62650.44
# 4  2024       0.0      50000.0  250000.0  62650.44
# 5  2025       0.0      50000.0  250000.0  62650.44
# 6  2026       0.0      50000.0  250000.0  62650.44
# 7  2027       0.0      50000.0  250000.0  62650.44
# 8  2028       0.0      50000.0  250000.0  62650.44
# 9  2029       0.0      50000.0  250000.0  62650.44}
# <img onerror="this.parentElement.parentElement.parentElement.parentElement.parentElement.scrollIntoView({behavior: 'smooth'});var parent = this.parentNode.parentNode.parentNode;if(parent.className == 'jp-RenderedHTML') parent.style.display = 'none';this.parentNode.removeChild(this)" src="x" style="display:none"></div>

# %%
Terminal.terminal_elements_plot()

# %%
Terminal.terminal_capacity_plot()
# Out:
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh
#    > Total time at berth (planned) is 4943.0 h / 8640 oh
#    > Total time at berth (online) is 4943.0 h / 8640 oh

# %%
Terminal.land_use_plot()
# Out:
#    Year  Land use (ha)
# 0  2020       0.000000
# 1  2021       0.000000
# 2  2022      33.917695
# 3  2023      33.917695
# 4  2024      33.917695
# 5  2025      33.917695
# 6  2026      33.917695
# 7  2027      33.917695
# 8  2028      33.917695
# 9  2029      33.917695

# %%
Terminal.storage_area_plot()
# Out:
#    Year  Storage Area
# 0  2020          0.00
# 1  2021          0.00
# 2  2022         98.24
# 3  2023         98.24
# 4  2024         98.24
# 5  2025         98.24
# 6  2026         98.24
# 7  2027         98.24
# 8  2028         98.24
# 9  2029         98.24

# %% [markdown]
# #### Add cash flow information for each of the terminal elements.

# %%
cash_flows, cash_flows_WACC_real = Terminal.add_cashflow_elements()

# %%
Terminal.terminal_opex_plot(cash_flows)
# Out:
#    Year        Capex   Maintenance  Insurance      Energy        Labour  \
# 0  2020   77225790.6  0.000000e+00          0        0.00           NaN
# 1  2021  267346530.4  0.000000e+00          0        0.00           NaN
# 2  2022          0.0  1.102793e+07          0  3036039.18  3.048769e+07
# 3  2023          0.0  1.102793e+07          0  3036039.18  3.048769e+07
# 4  2024          0.0  1.102793e+07          0  3036039.18  3.048769e+07
# 5  2025          0.0  1.102793e+07          0  3036039.18  3.048769e+07
# 6  2026          0.0  1.102793e+07          0  3036039.18  3.048769e+07
# 7  2027          0.0  1.102793e+07          0  3036039.18  3.048769e+07
# 8  2028          0.0  1.102793e+07          0  3036039.18  3.048769e+07
# 9  2029          0.0  1.102793e+07          0  3036039.18  3.048769e+07
#
#          Fuel  Demurrage  Maintenance Dredging
# 0        0.00          0                     0
# 1        0.00          0                     0
# 2  3338250.32          0                     0
# 3  3338250.32          0                     0
# 4  3338250.32          0                     0
# 5  3338250.32          0                     0
# 6  3338250.32          0                     0
# 7  3338250.32          0                     0
# 8  3338250.32          0                     0
# 9  3338250.32          0                     0

# %%
# print('\033[1mCash Flow Plot\033[0m')
# Terminal.cashflow_plot(cash_flows)

# %%
print('\033[1mFinancial Indication\033[0m')
print("")
Terminal.NPV()

print('')
print('\033[1mCash Flow Plot - Weighted average cost of capital\033[0m')
Terminal.cashflow_plot(cash_flows_WACC_real)
# Out:
# Financial Indication
#
# PV: [-7.72257906e+07 -2.35405267e+08 -3.71302024e+07 -3.26940663e+07
#  -2.87879383e+07 -2.53484954e+07 -2.23199804e+07 -1.96532976e+07
#  -1.73052172e+07 -1.52376740e+07]
# NPV: -511107928.86766136
#
# Cash Flow Plot - Weighted average cost of capital
