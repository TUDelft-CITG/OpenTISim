# %% [markdown]
# # MSc Thesis - Hugo Stam

# %% [markdown]
# #### Investment Strategy Simulation - Adaptive terminal planning in the light of an uncertain future

# %% [markdown]
# * [**0. Prepare inputs:**](#0.-Prepare-inputs)<br>
#    * [**0.1 Generate demand forecast scenario:**](#0.1-Generate-demand-forecast-scenario)<br>
#    * [**0.2 Generate vessels:**](#0.2-Generate-vessels)<br>
# * [**1. Instatiate system components:**](#1.-Instatiate-system-components)<br>
# * [**2. Start simulation:**](#2.-Strart-simulation)<br>
# * [**3. Report all elements:**](#3.-Report-all-elements)<br>

# %%
import numpy as np
import pandas as pd
import statistics as st

import matplotlib.pyplot as plt
import matplotlib as mpl

from terminal_optimization import container_objects
from terminal_optimization import container_defaults
from terminal_optimization import container_system

# %% [markdown]
# # 0. Prepare inputs

# %%
startyear = 2020
lifecycle = 15

# %% [markdown]
# ## 0.1 Generate demand forecast scenario

# %%
years = list(range(startyear, startyear+lifecycle))

demand = []
for year in years:
    if year <= 2025:
        demand.append(1_000_000)
    elif year <= 2030:
        demand.append(1_500_000)
    else:
        demand.append(2_000_000)

scenario_data={'year': years, 'volume': demand}

# ladens
container_defaults.container_data['historic_data'] = []
container = container_objects.Commodity(**container_defaults.container_data)
container.scenario_data = pd.DataFrame(data=scenario_data)

# combine
demand = [container]

# plot scenarios 
if False:
    laden.plot_demand()

# %% [markdown]
# ## 0.2 Generate vessels

# %%
# instantiate vessels
fully_cellular = container_objects.Vessel(**container_defaults.fully_cellular_data)
panamax = container_objects.Vessel(**container_defaults.panamax_data)
panamax_max = container_objects.Vessel(**container_defaults.panamax_max_data)
post_panamax_I = container_objects.Vessel(**container_defaults.post_panamax_I_data)
post_panamax_II = container_objects.Vessel(**container_defaults.post_panamax_II_data)
new_panamax = container_objects.Vessel(**container_defaults.new_panamax_data)
VLCS = container_objects.Vessel(**container_defaults.VLCS_data)
ULCS = container_objects.Vessel(**container_defaults.ULCS_data)

vessels = [fully_cellular, panamax, panamax_max, post_panamax_I, post_panamax_II, new_panamax, VLCS, ULCS]

# %% [markdown]
# # 1. Instatiate system components

# %% [markdown]
# ## 1.1 Terminal system

# %%
Terminal = container_system.System(startyear = startyear, 
                        lifecycle = lifecycle, 
                        elements = demand + vessels, 
                        operational_hours = 7500,
                        debug=True)

# %% [markdown]
# # 2. Start simulation

# %% [markdown]
# This method automatically generates investment decisions, parametrically derived from overall demand trends and a number of investment triggers.
#
# Apply frame of reference style decisions while stepping through each year of the terminal lifecycle and check if investment is needed (in light of strategic objective, operational objective, QSC, decision recipe, intervention method):
#     1. for each year evaluate the demand of each commodity (see 0.1 Demand forecast scenario)
#     2. for each year evaluate the various investment decisions
#     3. for each year calculate the energy costs (requires insight in realized demands)
#     4. for each year calculate the demurrage costs (requires insight in realized demands)
#     5. for each year calculate terminal revenues
#     6. collect all cash flows (capex, opex, revenues)
#     7. calculate PV's and aggregate to NPV

# %%
Terminal.simulate()
# Out:
# Below, the various investment decisions are evaluated for the year 2020.
#
# Simulate year: 2020
#   Total vessel calls: 295
#   Fully cellular calls: 0
#   Panamax calls: 295
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 0 [] is online; 0 total planned
#      a total of 0 [] is online; 0 total planned
#      a total of 0 [] is online; 0 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): inf
#      Berth occupancy online (@ start of year): inf
#      Crane occupancy planned (@ start of year): inf
#      Crane occupancy online (@ start of year): inf
#      waiting time factor (@ start of year): inf
#      waiting time occupancy (@ start of year): inf
#   *** add Berth to elements
#      Berth occupancy planned (after adding berth): inf
#      Berth occupancy online (after adding berth): inf
#   *** add Quay to elements
#      Berth occupancy planned (after adding quay): inf
#      Berth occupancy online (after adding quay): inf
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 2.7592704402515724
#      Berth occupancy online (after adding crane): inf
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 1.497635220125786
#      Berth occupancy online (after adding crane): inf
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 1.077090146750524
#      Berth occupancy online (after adding crane): inf
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.866817610062893
#      Berth occupancy online (after adding crane): inf
#   *** add Berth to elements
#      Berth occupancy planned (after adding berth): 0.748817610062893
#      Berth occupancy online (after adding berth): inf
#   *** add Quay to elements
#      Berth occupancy planned (after adding quay): 0.748817610062893
#      Berth occupancy online (after adding quay): inf
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.6226540880503145
#      Berth occupancy online (after adding crane): inf
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.538545073375262
#      Berth occupancy online (after adding crane): inf
#      Horizontal transport online (@ start of year): 0
#      Number of STS cranes (@start of year): 0
#      Stack capacity planned (@ start of year): 0
#      Stack capacity online (@ start of year): 0
#      Stack capacity required (@ start of year): 13905.76923076923
#      Total laden and reefer ground slots required (@ start of year): 3476.4423076923076
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#      Empty stack capacity planned (@ start of year): 0
#      Empty stack capacity online (@ start of year): 0
#      Empty stack capacity required (@ start of year): 1923.0769230769229
#      Empty ground slots required (@ start of year): 320.5128205128205
#   *** add empty stack to elements
#   *** add empty stack to elements
#   *** add empty stack to elements
#   *** add empty stack to elements
#   *** add empty stack to elements
#      OOG slots planned (@ start of year): 0
#      OOG slots online (@ start of year): 0
#      OOG slots required (@ start of year): 482.4924179762889
#   *** add OOG stack to elements
#   *** add OOG stack to elements
#   *** add OOG stack to elements
#   *** add OOG stack to elements
#   *** add OOG stack to elements
#      Number of stack equipment online (@ start of year): 0
#      Gate capacity planned (@ start of year): 0
#      Gate capacity online (@ start of year): 0
#      Gate service rate planned (@ start of year): inf
#      Gate lane minutes  (@ start of year): 0
#   *** add gate to elements
#   *** add gate to elements
#   *** add gate to elements
#   *** add gate to elements
#      Empty handlers online (@ start of year): 0
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#
# Below, the various investment decisions are evaluated for the year 2021.
#
# Simulate year: 2021
#   Total vessel calls: 295
#   Fully cellular calls: 0
#   Panamax calls: 295
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 2 Berth_01 is online; 2 total planned
#      a total of 0 Quay_01 is online; 2 total planned
#      a total of 0 STS_crane is online; 6 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.538545073375262
#      Berth occupancy online (@ start of year): inf
#      Crane occupancy planned (@ start of year): 0.42054507337526204
#      Crane occupancy online (@ start of year): inf
#      waiting time factor (@ start of year): 0
#      waiting time occupancy (@ start of year): nan
#      Horizontal transport online (@ start of year): 0
#      Number of STS cranes (@start of year): 0
#      Stack capacity planned (@ start of year): 14080
#      Stack capacity online (@ start of year): 0
#      Stack capacity required (@ start of year): 13905.76923076923
#      Total laden and reefer ground slots required (@ start of year): 3476.4423076923076
#      Empty stack capacity planned (@ start of year): 2400
#      Empty stack capacity online (@ start of year): 0
#      Empty stack capacity required (@ start of year): 1923.0769230769229
#      Empty ground slots required (@ start of year): 320.5128205128205
#      OOG slots planned (@ start of year): 500
#      OOG slots online (@ start of year): 0
#      OOG slots required (@ start of year): 482.4924179762889
#      Number of stack equipment online (@ start of year): 0
#      Gate capacity planned (@ start of year): 240
#      Gate capacity online (@ start of year): 0
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 216.35732009925556
#      Empty handlers online (@ start of year): 30
#   *** add general services to elements
#
# Below, the various investment decisions are evaluated for the year 2022.
#
# Simulate year: 2022
#   Total vessel calls: 295
#   Fully cellular calls: 0
#   Panamax calls: 295
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 2 Berth_01 is online; 2 total planned
#      a total of 2 Quay_01 is online; 2 total planned
#      a total of 6 STS_crane is online; 6 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.538545073375262
#      Berth occupancy online (@ start of year): 0.538545073375262
#      Crane occupancy planned (@ start of year): 0.42054507337526204
#      Crane occupancy online (@ start of year): 0.42054507337526204
#      waiting time factor (@ start of year): 0.14398030957202745
#      waiting time occupancy (@ start of year): 0.06055020985356123
#      Horizontal transport online (@ start of year): 0
#      Number of STS cranes (@start of year): 6
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#      Stack capacity planned (@ start of year): 14080
#      Stack capacity online (@ start of year): 14080
#      Stack capacity required (@ start of year): 13905.76923076923
#      Total laden and reefer ground slots required (@ start of year): 3476.4423076923076
#      Empty stack capacity planned (@ start of year): 2400
#      Empty stack capacity online (@ start of year): 2400
#      Empty stack capacity required (@ start of year): 1923.0769230769229
#      Empty ground slots required (@ start of year): 320.5128205128205
#      OOG slots planned (@ start of year): 500
#      OOG slots online (@ start of year): 500
#      OOG slots required (@ start of year): 482.4924179762889
#      Number of stack equipment online (@ start of year): 0
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#      Gate capacity planned (@ start of year): 240
#      Gate capacity online (@ start of year): 240
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 216.35732009925556
#      Empty handlers online (@ start of year): 30
#
# Below, the various investment decisions are evaluated for the year 2023.
#
# Simulate year: 2023
#   Total vessel calls: 295
#   Fully cellular calls: 0
#   Panamax calls: 295
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 2 Berth_01 is online; 2 total planned
#      a total of 2 Quay_01 is online; 2 total planned
#      a total of 6 STS_crane is online; 6 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.538545073375262
#      Berth occupancy online (@ start of year): 0.538545073375262
#      Crane occupancy planned (@ start of year): 0.42054507337526204
#      Crane occupancy online (@ start of year): 0.42054507337526204
#      waiting time factor (@ start of year): 0.14398030957202745
#      waiting time occupancy (@ start of year): 0.06055020985356123
#      Horizontal transport online (@ start of year): 30
#      Number of STS cranes (@start of year): 6
#      Stack capacity planned (@ start of year): 14080
#      Stack capacity online (@ start of year): 14080
#      Stack capacity required (@ start of year): 13905.76923076923
#      Total laden and reefer ground slots required (@ start of year): 3476.4423076923076
#      Empty stack capacity planned (@ start of year): 2400
#      Empty stack capacity online (@ start of year): 2400
#      Empty stack capacity required (@ start of year): 1923.0769230769229
#      Empty ground slots required (@ start of year): 320.5128205128205
#      OOG slots planned (@ start of year): 500
#      OOG slots online (@ start of year): 500
#      OOG slots required (@ start of year): 482.4924179762889
#      Number of stack equipment online (@ start of year): 24
#      Gate capacity planned (@ start of year): 240
#      Gate capacity online (@ start of year): 240
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 216.35732009925556
#      Empty handlers online (@ start of year): 30
#
# Below, the various investment decisions are evaluated for the year 2024.
#
# Simulate year: 2024
#   Total vessel calls: 295
#   Fully cellular calls: 0
#   Panamax calls: 295
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 2 Berth_01 is online; 2 total planned
#      a total of 2 Quay_01 is online; 2 total planned
#      a total of 6 STS_crane is online; 6 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.538545073375262
#      Berth occupancy online (@ start of year): 0.538545073375262
#      Crane occupancy planned (@ start of year): 0.42054507337526204
#      Crane occupancy online (@ start of year): 0.42054507337526204
#      waiting time factor (@ start of year): 0.14398030957202745
#      waiting time occupancy (@ start of year): 0.06055020985356123
#      Horizontal transport online (@ start of year): 30
#      Number of STS cranes (@start of year): 6
#      Stack capacity planned (@ start of year): 14080
#      Stack capacity online (@ start of year): 14080
#      Stack capacity required (@ start of year): 13905.76923076923
#      Total laden and reefer ground slots required (@ start of year): 3476.4423076923076
#      Empty stack capacity planned (@ start of year): 2400
#      Empty stack capacity online (@ start of year): 2400
#      Empty stack capacity required (@ start of year): 1923.0769230769229
#      Empty ground slots required (@ start of year): 320.5128205128205
#      OOG slots planned (@ start of year): 500
#      OOG slots online (@ start of year): 500
#      OOG slots required (@ start of year): 482.4924179762889
#      Number of stack equipment online (@ start of year): 24
#      Gate capacity planned (@ start of year): 240
#      Gate capacity online (@ start of year): 240
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 216.35732009925556
#      Empty handlers online (@ start of year): 30
#
# Below, the various investment decisions are evaluated for the year 2025.
#
# Simulate year: 2025
#   Total vessel calls: 295
#   Fully cellular calls: 0
#   Panamax calls: 295
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1000000
#      a total of 2 Berth_01 is online; 2 total planned
#      a total of 2 Quay_01 is online; 2 total planned
#      a total of 6 STS_crane is online; 6 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.538545073375262
#      Berth occupancy online (@ start of year): 0.538545073375262
#      Crane occupancy planned (@ start of year): 0.42054507337526204
#      Crane occupancy online (@ start of year): 0.42054507337526204
#      waiting time factor (@ start of year): 0.14398030957202745
#      waiting time occupancy (@ start of year): 0.06055020985356123
#      Horizontal transport online (@ start of year): 30
#      Number of STS cranes (@start of year): 6
#      Stack capacity planned (@ start of year): 14080
#      Stack capacity online (@ start of year): 14080
#      Stack capacity required (@ start of year): 13905.76923076923
#      Total laden and reefer ground slots required (@ start of year): 3476.4423076923076
#      Empty stack capacity planned (@ start of year): 2400
#      Empty stack capacity online (@ start of year): 2400
#      Empty stack capacity required (@ start of year): 1923.0769230769229
#      Empty ground slots required (@ start of year): 320.5128205128205
#      OOG slots planned (@ start of year): 500
#      OOG slots online (@ start of year): 500
#      OOG slots required (@ start of year): 482.4924179762889
#      Number of stack equipment online (@ start of year): 24
#      Gate capacity planned (@ start of year): 240
#      Gate capacity online (@ start of year): 240
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 216.35732009925556
#      Empty handlers online (@ start of year): 30
#
# Below, the various investment decisions are evaluated for the year 2026.
#
# Simulate year: 2026
#   Total vessel calls: 442
#   Fully cellular calls: 0
#   Panamax calls: 442
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1500000
#      a total of 2 Berth_01 is online; 2 total planned
#      a total of 2 Quay_01 is online; 2 total planned
#      a total of 6 STS_crane is online; 6 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.806904821802935
#      Berth occupancy online (@ start of year): 0.806904821802935
#      Crane occupancy planned (@ start of year): 0.630104821802935
#      Crane occupancy online (@ start of year): 0.630104821802935
#      waiting time factor (@ start of year): 0.9433407688919243
#      waiting time occupancy (@ start of year): 0.5944035670820896
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.7168898472596587
#      Berth occupancy online (after adding crane): 0.806904821802935
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.6493786163522012
#      Berth occupancy online (after adding crane): 0.806904821802935
#   *** add Berth to elements
#      Berth occupancy planned (after adding berth): 0.5904452830188679
#      Berth occupancy online (after adding berth): 0.7479714884696017
#   *** add Quay to elements
#      Berth occupancy planned (after adding quay): 0.5904452830188679
#      Berth occupancy online (after adding quay): 0.7479714884696017
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.5379365478686233
#      Berth occupancy online (after adding crane): 0.7479714884696017
#      Horizontal transport online (@ start of year): 30
#      Number of STS cranes (@start of year): 6
#      Stack capacity planned (@ start of year): 14080
#      Stack capacity online (@ start of year): 14080
#      Stack capacity required (@ start of year): 20858.653846153848
#      Total laden and reefer ground slots required (@ start of year): 5214.663461538462
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#      Empty stack capacity planned (@ start of year): 2400
#      Empty stack capacity online (@ start of year): 2400
#      Empty stack capacity required (@ start of year): 2884.6153846153848
#      Empty ground slots required (@ start of year): 480.7692307692308
#   *** add empty stack to elements
#   *** add empty stack to elements
#      OOG slots planned (@ start of year): 500
#      OOG slots online (@ start of year): 500
#      OOG slots required (@ start of year): 723.7386269644334
#   *** add OOG stack to elements
#   *** add OOG stack to elements
#   *** add OOG stack to elements
#      Number of stack equipment online (@ start of year): 24
#      Gate capacity planned (@ start of year): 240
#      Gate capacity online (@ start of year): 240
#      Gate service rate planned (@ start of year): 1.3522332506203476
#      Gate lane minutes  (@ start of year): 324.5359801488834
#   *** add gate to elements
#   *** add gate to elements
#      Empty handlers online (@ start of year): 30
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#
# Below, the various investment decisions are evaluated for the year 2027.
#
# Simulate year: 2027
#   Total vessel calls: 442
#   Fully cellular calls: 0
#   Panamax calls: 442
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1500000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 2 Quay_01 is online; 3 total planned
#      a total of 8 STS_crane is online; 9 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.5379365478686233
#      Berth occupancy online (@ start of year): 0.5904452830188679
#      Crane occupancy planned (@ start of year): 0.4200698812019567
#      Crane occupancy online (@ start of year): 0.4725786163522012
#      waiting time factor (@ start of year): 0.08358695297457314
#      waiting time occupancy (@ start of year): 0.03950140658182028
#      Horizontal transport online (@ start of year): 30
#      Number of STS cranes (@start of year): 8
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#      Stack capacity planned (@ start of year): 21120
#      Stack capacity online (@ start of year): 21120
#      Stack capacity required (@ start of year): 20858.653846153848
#      Total laden and reefer ground slots required (@ start of year): 5214.663461538462
#      Empty stack capacity planned (@ start of year): 3360
#      Empty stack capacity online (@ start of year): 3360
#      Empty stack capacity required (@ start of year): 2884.6153846153848
#      Empty ground slots required (@ start of year): 480.7692307692308
#      OOG slots planned (@ start of year): 800
#      OOG slots online (@ start of year): 800
#      OOG slots required (@ start of year): 723.7386269644334
#      Number of stack equipment online (@ start of year): 24
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#      Gate capacity planned (@ start of year): 360
#      Gate capacity online (@ start of year): 360
#      Gate service rate planned (@ start of year): 0.9014888337468984
#      Gate lane minutes  (@ start of year): 324.5359801488834
#      Empty handlers online (@ start of year): 45
#
# Below, the various investment decisions are evaluated for the year 2028.
#
# Simulate year: 2028
#   Total vessel calls: 442
#   Fully cellular calls: 0
#   Panamax calls: 442
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1500000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 3 Quay_01 is online; 3 total planned
#      a total of 9 STS_crane is online; 9 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.5379365478686233
#      Berth occupancy online (@ start of year): 0.5379365478686233
#      Crane occupancy planned (@ start of year): 0.4200698812019567
#      Crane occupancy online (@ start of year): 0.4200698812019567
#      waiting time factor (@ start of year): 0.067815717590683
#      waiting time occupancy (@ start of year): 0.028487340431943654
#      Horizontal transport online (@ start of year): 40
#      Number of STS cranes (@start of year): 9
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#      Stack capacity planned (@ start of year): 21120
#      Stack capacity online (@ start of year): 21120
#      Stack capacity required (@ start of year): 20858.653846153848
#      Total laden and reefer ground slots required (@ start of year): 5214.663461538462
#      Empty stack capacity planned (@ start of year): 3360
#      Empty stack capacity online (@ start of year): 3360
#      Empty stack capacity required (@ start of year): 2884.6153846153848
#      Empty ground slots required (@ start of year): 480.7692307692308
#      OOG slots planned (@ start of year): 800
#      OOG slots online (@ start of year): 800
#      OOG slots required (@ start of year): 723.7386269644334
#      Number of stack equipment online (@ start of year): 32
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#      Gate capacity planned (@ start of year): 360
#      Gate capacity online (@ start of year): 360
#      Gate service rate planned (@ start of year): 0.9014888337468984
#      Gate lane minutes  (@ start of year): 324.5359801488834
#      Empty handlers online (@ start of year): 45
#
# Below, the various investment decisions are evaluated for the year 2029.
#
# Simulate year: 2029
#   Total vessel calls: 442
#   Fully cellular calls: 0
#   Panamax calls: 442
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1500000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 3 Quay_01 is online; 3 total planned
#      a total of 9 STS_crane is online; 9 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.5379365478686233
#      Berth occupancy online (@ start of year): 0.5379365478686233
#      Crane occupancy planned (@ start of year): 0.4200698812019567
#      Crane occupancy online (@ start of year): 0.4200698812019567
#      waiting time factor (@ start of year): 0.067815717590683
#      waiting time occupancy (@ start of year): 0.028487340431943654
#      Horizontal transport online (@ start of year): 45
#      Number of STS cranes (@start of year): 9
#      Stack capacity planned (@ start of year): 21120
#      Stack capacity online (@ start of year): 21120
#      Stack capacity required (@ start of year): 20858.653846153848
#      Total laden and reefer ground slots required (@ start of year): 5214.663461538462
#      Empty stack capacity planned (@ start of year): 3360
#      Empty stack capacity online (@ start of year): 3360
#      Empty stack capacity required (@ start of year): 2884.6153846153848
#      Empty ground slots required (@ start of year): 480.7692307692308
#      OOG slots planned (@ start of year): 800
#      OOG slots online (@ start of year): 800
#      OOG slots required (@ start of year): 723.7386269644334
#      Number of stack equipment online (@ start of year): 36
#      Gate capacity planned (@ start of year): 360
#      Gate capacity online (@ start of year): 360
#      Gate service rate planned (@ start of year): 0.9014888337468984
#      Gate lane minutes  (@ start of year): 324.5359801488834
#      Empty handlers online (@ start of year): 45
#
# Below, the various investment decisions are evaluated for the year 2030.
#
# Simulate year: 2030
#   Total vessel calls: 442
#   Fully cellular calls: 0
#   Panamax calls: 442
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 1500000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 3 Quay_01 is online; 3 total planned
#      a total of 9 STS_crane is online; 9 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.5379365478686233
#      Berth occupancy online (@ start of year): 0.5379365478686233
#      Crane occupancy planned (@ start of year): 0.4200698812019567
#      Crane occupancy online (@ start of year): 0.4200698812019567
#      waiting time factor (@ start of year): 0.067815717590683
#      waiting time occupancy (@ start of year): 0.028487340431943654
#      Horizontal transport online (@ start of year): 45
#      Number of STS cranes (@start of year): 9
#      Stack capacity planned (@ start of year): 21120
#      Stack capacity online (@ start of year): 21120
#      Stack capacity required (@ start of year): 20858.653846153848
#      Total laden and reefer ground slots required (@ start of year): 5214.663461538462
#      Empty stack capacity planned (@ start of year): 3360
#      Empty stack capacity online (@ start of year): 3360
#      Empty stack capacity required (@ start of year): 2884.6153846153848
#      Empty ground slots required (@ start of year): 480.7692307692308
#      OOG slots planned (@ start of year): 800
#      OOG slots online (@ start of year): 800
#      OOG slots required (@ start of year): 723.7386269644334
#      Number of stack equipment online (@ start of year): 36
#      Gate capacity planned (@ start of year): 360
#      Gate capacity online (@ start of year): 360
#      Gate service rate planned (@ start of year): 0.9014888337468984
#      Gate lane minutes  (@ start of year): 324.5359801488834
#      Empty handlers online (@ start of year): 45
#
# Below, the various investment decisions are evaluated for the year 2031.
#
# Simulate year: 2031
#   Total vessel calls: 589
#   Fully cellular calls: 0
#   Panamax calls: 589
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 2000000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 3 Quay_01 is online; 3 total planned
#      a total of 9 STS_crane is online; 9 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.7168430468204053
#      Berth occupancy online (@ start of year): 0.7168430468204053
#      Crane occupancy planned (@ start of year): 0.5597763801537387
#      Crane occupancy online (@ start of year): 0.5597763801537387
#      waiting time factor (@ start of year): 0.23081701297938534
#      waiting time occupancy (@ start of year): 0.12920591200349885
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.6608654088050314
#      Berth occupancy online (after adding crane): 0.7168430468204053
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.6150655231560892
#      Berth occupancy online (after adding crane): 0.7168430468204053
#   *** add STS crane to elements
#      Berth occupancy planned (after adding crane): 0.5768989517819706
#      Berth occupancy online (after adding crane): 0.7168430468204053
#      Horizontal transport online (@ start of year): 45
#      Number of STS cranes (@start of year): 9
#      Stack capacity planned (@ start of year): 21120
#      Stack capacity online (@ start of year): 21120
#      Stack capacity required (@ start of year): 27811.53846153846
#      Total laden and reefer ground slots required (@ start of year): 6952.884615384615
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#   *** add laden stack to elements
#      Empty stack capacity planned (@ start of year): 3360
#      Empty stack capacity online (@ start of year): 3360
#      Empty stack capacity required (@ start of year): 3846.1538461538457
#      Empty ground slots required (@ start of year): 641.025641025641
#   *** add empty stack to elements
#   *** add empty stack to elements
#      OOG slots planned (@ start of year): 800
#      OOG slots online (@ start of year): 800
#      OOG slots required (@ start of year): 964.9848359525778
#   *** add OOG stack to elements
#   *** add OOG stack to elements
#      Number of stack equipment online (@ start of year): 36
#      Gate capacity planned (@ start of year): 360
#      Gate capacity online (@ start of year): 360
#      Gate service rate planned (@ start of year): 1.2019851116625309
#      Gate lane minutes  (@ start of year): 432.7146401985111
#   *** add gate to elements
#   *** add gate to elements
#      Empty handlers online (@ start of year): 45
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#
# Below, the various investment decisions are evaluated for the year 2032.
#
# Simulate year: 2032
#   Total vessel calls: 589
#   Fully cellular calls: 0
#   Panamax calls: 589
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 2000000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 3 Quay_01 is online; 3 total planned
#      a total of 12 STS_crane is online; 12 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.5768989517819706
#      Berth occupancy online (@ start of year): 0.5768989517819706
#      Crane occupancy planned (@ start of year): 0.41983228511530396
#      Crane occupancy online (@ start of year): 0.41983228511530396
#      waiting time factor (@ start of year): 0.07818738073376047
#      waiting time occupancy (@ start of year): 0.03282558672063495
#      Horizontal transport online (@ start of year): 45
#      Number of STS cranes (@start of year): 12
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#   *** add tractor to elements
#      Stack capacity planned (@ start of year): 27840
#      Stack capacity online (@ start of year): 27840
#      Stack capacity required (@ start of year): 27811.53846153846
#      Total laden and reefer ground slots required (@ start of year): 6952.884615384615
#      Empty stack capacity planned (@ start of year): 4320
#      Empty stack capacity online (@ start of year): 4320
#      Empty stack capacity required (@ start of year): 3846.1538461538457
#      Empty ground slots required (@ start of year): 641.025641025641
#      OOG slots planned (@ start of year): 1000
#      OOG slots online (@ start of year): 1000
#      OOG slots required (@ start of year): 964.9848359525778
#      Number of stack equipment online (@ start of year): 36
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#   *** add stack equipment to elements
#      Gate capacity planned (@ start of year): 480
#      Gate capacity online (@ start of year): 480
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 432.7146401985111
#      Empty handlers online (@ start of year): 60
#
# Below, the various investment decisions are evaluated for the year 2033.
#
# Simulate year: 2033
#   Total vessel calls: 589
#   Fully cellular calls: 0
#   Panamax calls: 589
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 2000000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 3 Quay_01 is online; 3 total planned
#      a total of 12 STS_crane is online; 12 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.5768989517819706
#      Berth occupancy online (@ start of year): 0.5768989517819706
#      Crane occupancy planned (@ start of year): 0.41983228511530396
#      Crane occupancy online (@ start of year): 0.41983228511530396
#      waiting time factor (@ start of year): 0.07818738073376047
#      waiting time occupancy (@ start of year): 0.03282558672063495
#      Horizontal transport online (@ start of year): 60
#      Number of STS cranes (@start of year): 12
#      Stack capacity planned (@ start of year): 27840
#      Stack capacity online (@ start of year): 27840
#      Stack capacity required (@ start of year): 27811.53846153846
#      Total laden and reefer ground slots required (@ start of year): 6952.884615384615
#      Empty stack capacity planned (@ start of year): 4320
#      Empty stack capacity online (@ start of year): 4320
#      Empty stack capacity required (@ start of year): 3846.1538461538457
#      Empty ground slots required (@ start of year): 641.025641025641
#      OOG slots planned (@ start of year): 1000
#      OOG slots online (@ start of year): 1000
#      OOG slots required (@ start of year): 964.9848359525778
#      Number of stack equipment online (@ start of year): 48
#      Gate capacity planned (@ start of year): 480
#      Gate capacity online (@ start of year): 480
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 432.7146401985111
#      Empty handlers online (@ start of year): 60
#
# Below, the various investment decisions are evaluated for the year 2034.
#
# Simulate year: 2034
#   Total vessel calls: 589
#   Fully cellular calls: 0
#   Panamax calls: 589
#   Panamax max calls: 0
#   Post Panamax I calls: 0
#   Post Panamax II calls: 0
#   New Panamax calls: 0
#   VLCS calls: 0
#   ULCS calls: 0
#   Total cargo volume: 2000000
#      a total of 3 Berth_01 is online; 3 total planned
#      a total of 3 Quay_01 is online; 3 total planned
#      a total of 12 STS_crane is online; 12 total planned
#
#   Start analysis:
#      Berth occupancy planned (@ start of year): 0.5768989517819706
#      Berth occupancy online (@ start of year): 0.5768989517819706
#      Crane occupancy planned (@ start of year): 0.41983228511530396
#      Crane occupancy online (@ start of year): 0.41983228511530396
#      waiting time factor (@ start of year): 0.07818738073376047
#      waiting time occupancy (@ start of year): 0.03282558672063495
#      Horizontal transport online (@ start of year): 60
#      Number of STS cranes (@start of year): 12
#      Stack capacity planned (@ start of year): 27840
#      Stack capacity online (@ start of year): 27840
#      Stack capacity required (@ start of year): 27811.53846153846
#      Total laden and reefer ground slots required (@ start of year): 6952.884615384615
#      Empty stack capacity planned (@ start of year): 4320
#      Empty stack capacity online (@ start of year): 4320
#      Empty stack capacity required (@ start of year): 3846.1538461538457
#      Empty ground slots required (@ start of year): 641.025641025641
#      OOG slots planned (@ start of year): 1000
#      OOG slots online (@ start of year): 1000
#      OOG slots required (@ start of year): 964.9848359525778
#      Number of stack equipment online (@ start of year): 48
#      Gate capacity planned (@ start of year): 480
#      Gate capacity online (@ start of year): 480
#      Gate service rate planned (@ start of year): 0.9014888337468981
#      Gate lane minutes  (@ start of year): 432.7146401985111
#      Empty handlers online (@ start of year): 60
# PV: [-5.14838604e+07 -2.08689254e+08 -3.29296775e+07 -2.89953998e+07
#  -2.55311704e+07 -2.24808303e+07 -6.70485377e+07 -3.70100387e+07
#  -2.27175222e+07 -2.00033431e+07 -1.76134409e+07 -3.68673001e+07
#  -1.78639015e+07 -1.57296094e+07 -1.38503122e+07]
# NPV: -618814198.3672526

# %% [markdown]
# ## 3. Report all elements

# %%
if True: 
    for element in Terminal.elements:
        print("")
        print(element.name)
        print("")
        print(element.__dict__) # This is the dictionary containing the module's symbol table. 
        # object.__dict__ A dictionary or other mapping object used to store an object's (writable) attributes.
# Out:
# Laden
#
# {'historic_data': [], 'scenario_data':     year   volume
# 0   2020  1000000
# 1   2021  1000000
# 2   2022  1000000
# 3   2023  1000000
# 4   2024  1000000
# 5   2025  1000000
# 6   2026  1500000
# 7   2027  1500000
# 8   2028  1500000
# 9   2029  1500000
# 10  2030  1500000
# 11  2031  2000000
# 12  2032  2000000
# 13  2033  2000000
# 14  2034  2000000, 'handling_fee': 150, 'fully_cellular_perc': 0, 'panamax_perc': 100, 'panamax_max_perc': 0, 'post_panamax_I_perc': 0, 'post_panamax_II_perc': 0, 'new_panamax_perc': 0, 'VLCS_perc': 0, 'ULCS_perc': 0, 'name': 'Laden', 'id': 'fec3c77a-ac93-11e9-95fa-0050b697a632'}
#
# Fully_Cellular_1
#
# {'type': 'Fully_Cellular', 'call_size': 2500, 'LOA': 215, 'draught': 10.0, 'beam': 20.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 30, 'variable_fee': 0.045, 'name': 'Fully_Cellular_1', 'id': 'fec4d836-ac93-11e9-8f09-0050b697a632'}
#
# Panamax_1
#
# {'type': 'Panamax', 'call_size': 3400, 'LOA': 250, 'draught': 12.5, 'beam': 32.2, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 34, 'variable_fee': 0.04, 'name': 'Panamax_1', 'id': 'fec4d837-ac93-11e9-89fc-0050b697a632'}
#
# Panamax_Max_1
#
# {'type': 'Panamax_Max', 'call_size': 4500, 'LOA': 290, 'draught': 12.5, 'beam': 32.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 38, 'variable_fee': 0.035, 'name': 'Panamax_Max_1', 'id': 'fec4d838-ac93-11e9-b496-0050b697a632'}
#
# Post_Panamax_I_1
#
# {'type': 'Post_Panamax_I', 'call_size': 6000, 'LOA': 300, 'draught': 13.0, 'beam': 40.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 42, 'variable_fee': 0.03, 'name': 'Post_Panamax_I_1', 'id': 'fec4d839-ac93-11e9-937a-0050b697a632'}
#
# Post_Panamax_II_1
#
# {'type': 'Post_Panamax_II', 'call_size': 8500, 'LOA': 340, 'draught': 14.5, 'beam': 43.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 46, 'variable_fee': 0.025, 'name': 'Post_Panamax_II_1', 'id': 'fec4d83a-ac93-11e9-91b1-0050b697a632'}
#
# New_Panamax_1
#
# {'type': 'New_Panamax', 'call_size': 12500, 'LOA': 366, 'draught': 15.2, 'beam': 49.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 50, 'variable_fee': 0.02, 'name': 'New_Panamax_1', 'id': 'fec4d83b-ac93-11e9-ba5c-0050b697a632'}
#
# VLCS_1
#
# {'type': 'VLCS', 'call_size': 15000, 'LOA': 397, 'draught': 15.5, 'beam': 56.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 54, 'variable_fee': 0.015, 'name': 'VLCS_1', 'id': 'fec4d83c-ac93-11e9-a9e8-0050b697a632'}
#
# ULCS_1
#
# {'type': 'ULCS', 'call_size': 21000, 'LOA': 400, 'draught': 16.0, 'beam': 59.0, 'max_cranes': 4, 'all_turn_time': 31, 'mooring_time': 6, 'demurrage_rate': 730, 'starting_fee': 60, 'variable_fee': 0.01, 'name': 'ULCS_1', 'id': 'fec4d83d-ac93-11e9-ba16-0050b697a632'}
#
# Berth_01
#
# {'triggers': [], 'renevue': [], 'labour': [], 'maintenance': [], 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': [], 'crane_type': 'Mobile cranes', 'max_cranes': 4, 'delivery_time': 1, 'year_purchase': [], 'year_online': 2021, 'name': 'Berth_01', 'id': 'fec87f3a-ac93-11e9-8cff-0050b697a632'}
#
# Quay_01
#
# {'land_use': 28165.0, 'triggers': [], 'renevue': [], 'labour': [], 'maintenance': 345371.7, 'energy': [], 'insurance': 345371.7, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 40557795, 'year_purchase': [], 'year_online': 2022, 'ownership': 'Port authority', 'delivery_time': 2, 'lifespan': 50, 'mobilisation_min': 2500000, 'mobilisation_perc': 0.02, 'maintenance_perc': 0.01, 'insurance_perc': 0.01, 'freeboard': 4, 'Gijt_constant': 757.8, 'Gijt_coefficient': 1.2729, 'max_sinkage': 0.5, 'wave_motion': 0.5, 'safety_margin': 0.5, 'apron_width': 65.5, 'apron_pavement': 125, 'name': 'Quay_01', 'id': 'fec87f3c-ac93-11e9-a950-0050b697a632', 'df':     year       capex  maintenance  insurance
# 0   2020  24334677.0          0.0        0.0
# 1   2021  16223118.0          0.0        0.0
# 2   2022         0.0     345371.7   345371.7
# 3   2023         0.0     345371.7   345371.7
# 4   2024         0.0     345371.7   345371.7
# 5   2025         0.0     345371.7   345371.7
# 6   2026         0.0     345371.7   345371.7
# 7   2027         0.0     345371.7   345371.7
# 8   2028         0.0     345371.7   345371.7
# 9   2029         0.0     345371.7   345371.7
# 10  2030         0.0     345371.7   345371.7
# 11  2031         0.0     345371.7   345371.7
# 12  2032         0.0     345371.7   345371.7
# 13  2033         0.0     345371.7   345371.7
# 14  2034         0.0     345371.7   345371.7}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 793269.2307692308, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 1, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 53, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fec98fe8-ac93-11e9-8eb1-0050b697a632', 'shift': 31.73076923076923, 'df':     year       capex  maintenance  insurance         labour         energy
# 0   2020         0.0          0.0        0.0       0.000000       0.000000
# 1   2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2   2022         0.0     200000.0   100000.0  793269.230769  144565.284178
# 3   2023         0.0     200000.0   100000.0  793269.230769  144565.284178
# 4   2024         0.0     200000.0   100000.0  793269.230769  144565.284178
# 5   2025         0.0     200000.0   100000.0  793269.230769  144565.284178
# 6   2026         0.0     200000.0   100000.0  793269.230769  216847.926267
# 7   2027         0.0     200000.0   100000.0  793269.230769  162635.944700
# 8   2028         0.0     200000.0   100000.0  793269.230769  144565.284178
# 9   2029         0.0     200000.0   100000.0  793269.230769  144565.284178
# 10  2030         0.0     200000.0   100000.0  793269.230769  144565.284178
# 11  2031         0.0     200000.0   100000.0  793269.230769  192753.712238
# 12  2032         0.0     200000.0   100000.0  793269.230769  144565.284178
# 13  2033         0.0     200000.0   100000.0  793269.230769  144565.284178
# 14  2034         0.0     200000.0   100000.0  793269.230769  144565.284178}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 793269.2307692308, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 1, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 53, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fecb3c76-ac93-11e9-b21f-0050b697a632', 'shift': 31.73076923076923, 'df':     year       capex  maintenance  insurance         labour         energy
# 0   2020         0.0          0.0        0.0       0.000000       0.000000
# 1   2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2   2022         0.0     200000.0   100000.0  793269.230769  144565.284178
# 3   2023         0.0     200000.0   100000.0  793269.230769  144565.284178
# 4   2024         0.0     200000.0   100000.0  793269.230769  144565.284178
# 5   2025         0.0     200000.0   100000.0  793269.230769  144565.284178
# 6   2026         0.0     200000.0   100000.0  793269.230769  216847.926267
# 7   2027         0.0     200000.0   100000.0  793269.230769  162635.944700
# 8   2028         0.0     200000.0   100000.0  793269.230769  144565.284178
# 9   2029         0.0     200000.0   100000.0  793269.230769  144565.284178
# 10  2030         0.0     200000.0   100000.0  793269.230769  144565.284178
# 11  2031         0.0     200000.0   100000.0  793269.230769  192753.712238
# 12  2032         0.0     200000.0   100000.0  793269.230769  144565.284178
# 13  2033         0.0     200000.0   100000.0  793269.230769  144565.284178
# 14  2034         0.0     200000.0   100000.0  793269.230769  144565.284178}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 793269.2307692308, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 1, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 53, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fecc4d28-ac93-11e9-8fac-0050b697a632', 'shift': 31.73076923076923, 'df':     year       capex  maintenance  insurance         labour         energy
# 0   2020         0.0          0.0        0.0       0.000000       0.000000
# 1   2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2   2022         0.0     200000.0   100000.0  793269.230769  144565.284178
# 3   2023         0.0     200000.0   100000.0  793269.230769  144565.284178
# 4   2024         0.0     200000.0   100000.0  793269.230769  144565.284178
# 5   2025         0.0     200000.0   100000.0  793269.230769  144565.284178
# 6   2026         0.0     200000.0   100000.0  793269.230769  216847.926267
# 7   2027         0.0     200000.0   100000.0  793269.230769  162635.944700
# 8   2028         0.0     200000.0   100000.0  793269.230769  144565.284178
# 9   2029         0.0     200000.0   100000.0  793269.230769  144565.284178
# 10  2030         0.0     200000.0   100000.0  793269.230769  144565.284178
# 11  2031         0.0     200000.0   100000.0  793269.230769  192753.712238
# 12  2032         0.0     200000.0   100000.0  793269.230769  144565.284178
# 13  2033         0.0     200000.0   100000.0  793269.230769  144565.284178
# 14  2034         0.0     200000.0   100000.0  793269.230769  144565.284178}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 793269.2307692308, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 1, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 53, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fecd84da-ac93-11e9-b6dc-0050b697a632', 'shift': 31.73076923076923, 'df':     year       capex  maintenance  insurance         labour         energy
# 0   2020         0.0          0.0        0.0       0.000000       0.000000
# 1   2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2   2022         0.0     200000.0   100000.0  793269.230769  144565.284178
# 3   2023         0.0     200000.0   100000.0  793269.230769  144565.284178
# 4   2024         0.0     200000.0   100000.0  793269.230769  144565.284178
# 5   2025         0.0     200000.0   100000.0  793269.230769  144565.284178
# 6   2026         0.0     200000.0   100000.0  793269.230769  216847.926267
# 7   2027         0.0     200000.0   100000.0  793269.230769  162635.944700
# 8   2028         0.0     200000.0   100000.0  793269.230769  144565.284178
# 9   2029         0.0     200000.0   100000.0  793269.230769  144565.284178
# 10  2030         0.0     200000.0   100000.0  793269.230769  144565.284178
# 11  2031         0.0     200000.0   100000.0  793269.230769  192753.712238
# 12  2032         0.0     200000.0   100000.0  793269.230769  144565.284178
# 13  2033         0.0     200000.0   100000.0  793269.230769  144565.284178
# 14  2034         0.0     200000.0   100000.0  793269.230769  144565.284178}
#
# Berth_01
#
# {'triggers': [], 'renevue': [], 'labour': [], 'maintenance': [], 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': [], 'crane_type': 'Mobile cranes', 'max_cranes': 4, 'delivery_time': 1, 'year_purchase': [], 'year_online': 2021, 'name': 'Berth_01', 'id': 'fece958c-ac93-11e9-9811-0050b697a632'}
#
# Quay_01
#
# {'land_use': 31636.500000000007, 'triggers': [], 'renevue': [], 'labour': [], 'maintenance': 387940.7700000001, 'energy': [], 'insurance': 387940.7700000001, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 45248639, 'year_purchase': [], 'year_online': 2022, 'ownership': 'Port authority', 'delivery_time': 2, 'lifespan': 50, 'mobilisation_min': 2500000, 'mobilisation_perc': 0.02, 'maintenance_perc': 0.01, 'insurance_perc': 0.01, 'freeboard': 4, 'Gijt_constant': 757.8, 'Gijt_coefficient': 1.2729, 'max_sinkage': 0.5, 'wave_motion': 0.5, 'safety_margin': 0.5, 'apron_width': 65.5, 'apron_pavement': 125, 'name': 'Quay_01', 'id': 'fece958e-ac93-11e9-b110-0050b697a632', 'df':     year       capex  maintenance  insurance
# 0   2020  27149183.4         0.00       0.00
# 1   2021  18099455.6         0.00       0.00
# 2   2022         0.0    387940.77  387940.77
# 3   2023         0.0    387940.77  387940.77
# 4   2024         0.0    387940.77  387940.77
# 5   2025         0.0    387940.77  387940.77
# 6   2026         0.0    387940.77  387940.77
# 7   2027         0.0    387940.77  387940.77
# 8   2028         0.0    387940.77  387940.77
# 9   2029         0.0    387940.77  387940.77
# 10  2030         0.0    387940.77  387940.77
# 11  2031         0.0    387940.77  387940.77
# 12  2032         0.0    387940.77  387940.77
# 13  2033         0.0    387940.77  387940.77
# 14  2034         0.0    387940.77  387940.77}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 793269.2307692308, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 1, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 53, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fecfa63a-ac93-11e9-b604-0050b697a632', 'shift': 31.73076923076923, 'df':     year       capex  maintenance  insurance         labour         energy
# 0   2020         0.0          0.0        0.0       0.000000       0.000000
# 1   2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2   2022         0.0     200000.0   100000.0  793269.230769  144565.284178
# 3   2023         0.0     200000.0   100000.0  793269.230769  144565.284178
# 4   2024         0.0     200000.0   100000.0  793269.230769  144565.284178
# 5   2025         0.0     200000.0   100000.0  793269.230769  144565.284178
# 6   2026         0.0     200000.0   100000.0  793269.230769  216847.926267
# 7   2027         0.0     200000.0   100000.0  793269.230769  162635.944700
# 8   2028         0.0     200000.0   100000.0  793269.230769  144565.284178
# 9   2029         0.0     200000.0   100000.0  793269.230769  144565.284178
# 10  2030         0.0     200000.0   100000.0  793269.230769  144565.284178
# 11  2031         0.0     200000.0   100000.0  793269.230769  192753.712238
# 12  2032         0.0     200000.0   100000.0  793269.230769  144565.284178
# 13  2033         0.0     200000.0   100000.0  793269.230769  144565.284178
# 14  2034         0.0     200000.0   100000.0  793269.230769  144565.284178}
#
# STS_crane
#
# {'triggers': [], 'renevue': [], 'labour': 793269.2307692308, 'maintenance': 200000.0, 'energy': [], 'insurance': 100000.0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 11500000, 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'unit_rate': 10000000, 'mobilisation_perc': 0.15, 'maintenance_perc': 0.02, 'consumption': 8, 'insurance_perc': 0.01, 'crew': 5.5, 'crane_type': 'STS crane', 'lifting_capacity': 2.13, 'hourly_cycles': 25, 'eff_fact': 1, 'payload': 2.13, 'peak_capacity': 53.25, 'effective_capacity': 53, 'year_purchase': [], 'year_online': 2022, 'name': 'STS_crane', 'id': 'fed09000-ac93-11e9-bf7f-0050b697a632', 'shift': 31.73076923076923, 'df':     year       capex  maintenance  insurance         labour         energy
# 0   2020         0.0          0.0        0.0       0.000000       0.000000
# 1   2021  11500000.0          0.0        0.0       0.000000       0.000000
# 2   2022         0.0     200000.0   100000.0  793269.230769  144565.284178
# 3   2023         0.0     200000.0   100000.0  793269.230769  144565.284178
# 4   2024         0.0     200000.0   100000.0  793269.230769  144565.284178
# 5   2025         0.0     200000.0   100000.0  793269.230769  144565.284178
# 6   2026         0.0     200000.0   100000.0  793269.230769  216847.926267
# 7   2027         0.0     200000.0   100000.0  793269.230769  162635.944700
# 8   2028         0.0     200000.0   100000.0  793269.230769  144565.284178
# 9   2029         0.0     200000.0   100000.0  793269.230769  144565.284178
# 10  2030         0.0     200000.0   100000.0  793269.230769  144565.284178
# 11  2031         0.0     200000.0   100000.0  793269.230769  192753.712238
# 12  2032         0.0     200000.0   100000.0  793269.230769  144565.284178
# 13  2033         0.0     200000.0   100000.0  793269.230769  144565.284178
# 14  2034         0.0     200000.0   100000.0  793269.230769  144565.284178}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed1c7b2-ac93-11e9-814b-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed28a76-ac93-11e9-bcda-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed32650-ac93-11e9-8916-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed3c226-ac93-11e9-aa23-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed4131c-ac93-11e9-8e37-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed41321-ac93-11e9-84ab-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed41326-ac93-11e9-b48f-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed6755e-ac93-11e9-becd-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed68920-ac93-11e9-84e6-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed68925-ac93-11e9-8ef6-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed6892a-ac93-11e9-99d2-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed912cc-ac93-11e9-b8bd-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed912d1-ac93-11e9-8a4a-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed912d6-ac93-11e9-b6eb-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fed912db-ac93-11e9-94d4-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fedb9c82-ac93-11e9-a207-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fedb9c87-ac93-11e9-b9cf-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fedb9c8c-ac93-11e9-aac5-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fedb9c91-ac93-11e9-a8b8-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# {'land_use': 4651.2, 'triggers': [], 'capex': 1312800, 'labour': [], 'maintenance': 116280, 'energy': [], 'insurance': [], 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'ownership': 'Terminal operator', 'delivery_time': 1, 'lifespan': 40, 'mobilisation': 10000, 'maintenance_perc': 0.1, 'width': 4, 'height': 4, 'length': 20, 'capacity': 320, 'gross_tgs': 18, 'area_factor': 3.23, 'pavement': 200, 'drainage': 50, 'household': 0.1, 'digout_margin': 1.2, 'reefer_factor': 2.33, 'consumption': 4, 'reefer_rack': 3500, 'reefers_present': 0.5, 'year_purchase': [], 'year_online': 2022, 'name': 'RS Stack', 'id': 'fede39dc-ac93-11e9-8ffe-0050b697a632', 'df':     year      capex  maintenance        energy
# 0   2020        0.0          0.0      0.000000
# 1   2021  1312800.0          0.0      0.000000
# 2   2022        0.0     116280.0  53078.784965
# 3   2023        0.0     116280.0  53078.784965
# 4   2024        0.0     116280.0  53078.784965
# 5   2025        0.0     116280.0  53078.784965
# 6   2026        0.0     116280.0  79618.177448
# 7   2027        0.0     116280.0  53078.784965
# 8   2028        0.0     116280.0  53078.784965
# 9   2029        0.0     116280.0  53078.784965
# 10  2030        0.0     116280.0  53078.784965
# 11  2031        0.0     116280.0  70771.713287
# 12  2032        0.0     116280.0  53688.885942
# 13  2033        0.0     116280.0  53688.885942
# 14  2034        0.0     116280.0  53688.885942}
#
# RS Stack
#
# ...
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}
#
# Reach stacker
#
# {'triggers': [], 'labour': 250000, 'maintenance': 50000.0, 'energy': [], 'insurance': 0, 'lease': [], 'demurrage': [], 'overseas_transport': [], 'residual': [], 'fuel': [], 'capex': 505000, 'type': 'rs', 'ownership': 'Terminal operator', 'delivery_time': 0, 'lifespan': 10, 'unit_rate': 500000, 'mobilisation': 5000, 'maintenance_perc': 0.1, 'insurance_perc': 0, 'crew': 2, 'salary': 50000, 'required': 4, 'fuel_consumption': 1, 'power_consumption': 0, 'year_purchase': [], 'year_online': 2032, 'name': 'Reach stacker', 'id': 'ffb6582e-ac93-11e9-a0fc-0050b697a632', 'shift': 10, 'df':     year     capex  maintenance    labour          fuel
# 0   2020       0.0          0.0       0.0      0.000000
# 1   2021       0.0          0.0       0.0      0.000000
# 2   2022       0.0          0.0       0.0      0.000000
# 3   2023       0.0          0.0       0.0      0.000000
# 4   2024       0.0          0.0       0.0      0.000000
# 5   2025       0.0          0.0       0.0      0.000000
# 6   2026       0.0          0.0       0.0      0.000000
# 7   2027       0.0          0.0       0.0      0.000000
# 8   2028       0.0          0.0       0.0      0.000000
# 9   2029       0.0          0.0       0.0      0.000000
# 10  2030       0.0          0.0       0.0      0.000000
# 11  2031  505000.0          0.0       0.0      0.000000
# 12  2032       0.0      50000.0  250000.0  47294.930876
# 13  2033       0.0      50000.0  250000.0  47294.930876
# 14  2034       0.0      50000.0  250000.0  47294.930876}

# %%
Terminal.terminal_elements_plot()

# %%
Terminal.terminal_capacity_plot()

# %%
Terminal.land_use_plot()

# %% [markdown]
# #### Add cash flow information for each of the terminal elements.

# %%
cash_flows, cash_flows_WACC_real = Terminal.add_cashflow_elements()

# %%
Terminal.opex_plot(cash_flows)
# Out:
#     year        capex   maintenance    insurance        energy        labour  \
# 0   2020   51483860.4  0.000000e+00        0.000  0.000000e+00           NaN
# 1   2021  237005521.6  0.000000e+00        0.000  0.000000e+00           NaN
# 2   2022          0.0  1.051402e+07  1333312.470  4.532241e+06  2.337346e+07
# 3   2023          0.0  1.051402e+07  1333312.470  4.532241e+06  2.337346e+07
# 4   2024          0.0  1.051402e+07  1333312.470  4.532241e+06  2.337346e+07
# 5   2025          0.0  1.051402e+07  1333312.470  4.532241e+06  2.337346e+07
# 6   2026   96946704.2  1.051402e+07  1333312.470  6.133670e+06  2.485346e+07
# 7   2027   31111286.8  1.475926e+07  1533312.470  6.155426e+06  3.254577e+07
# 8   2028          0.0  1.556841e+07  1999968.705  6.160509e+06  3.506019e+07
# 9   2029          0.0  1.556841e+07  1999968.705  6.160509e+06  3.506019e+07
# 10  2030          0.0  1.556841e+07  1999968.705  6.160509e+06  3.506019e+07
# 11  2031   82136974.0  1.556841e+07  1999968.705  7.761939e+06  3.654019e+07
# 12  2032          0.0  1.997187e+07  2299968.705  7.781816e+06  4.674692e+07
# 13  2033          0.0  1.997187e+07  2299968.705  7.781816e+06  4.674692e+07
# 14  2034          0.0  1.997187e+07  2299968.705  7.781816e+06  4.674692e+07
#
#             fuel  demurrage  overseas_transport
# 0   0.000000e+00          0                   0
# 1   0.000000e+00          0                   0
# 2   2.719116e+06          0                   0
# 3   2.719116e+06          0                   0
# 4   2.719116e+06          0                   0
# 5   2.719116e+06          0                   0
# 6   4.078675e+06          0                   0
# 7   4.078675e+06          0                   0
# 8   4.078675e+06          0                   0
# 9   4.078675e+06          0                   0
# 10  4.078675e+06          0                   0
# 11  5.438233e+06          0                   0
# 12  5.438233e+06          0                   0
# 13  5.438233e+06          0                   0
# 14  5.438233e+06          0                   0

# %%
Terminal.cashflow_plot(cash_flows)
Terminal.cashflow_plot(cash_flows_WACC_real)

# %%
Terminal.NPV()
# Out:
# PV: [-5.14838604e+07 -2.08689254e+08 -3.29296775e+07 -2.89953998e+07
#  -2.55311704e+07 -2.24808303e+07 -6.70485377e+07 -3.70100387e+07
#  -2.27175222e+07 -2.00033431e+07 -1.76134409e+07 -3.68673001e+07
#  -1.78639015e+07 -1.57296094e+07 -1.38503122e+07]
# NPV: -618814198.3672526

# %%
Terminal.WACC_nom()
# Out:
# 0.15839999999999999

# %%
Terminal.WACC_real(inflation=0.0)
# Out:
# 0.15839999999999987
